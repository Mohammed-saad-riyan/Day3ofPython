# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed-saad-riyan/Day3ofPython/blob/main/sleepanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import polars as pl
data= pl.read_csv("https://raw.githubusercontent.com/Nameera05/Datasets/main/Sleep_Efficiency1.csv")

# %%
data
# Out:
# shape: (452, 13)
# ┌─────┬─────┬────────┬──────────┬───┬─────────────┬─────────────────────┬─────────┬───────────┐
# │ ID  ┆ Age ┆ Gender ┆ Sleep    ┆ … ┆ Caffeine    ┆ Alcohol consumption ┆ Smoking ┆ Exercise  │
# │ --- ┆ --- ┆ ---    ┆ duration ┆   ┆ consumption ┆ ---                 ┆ status  ┆ frequency │
# │ i64 ┆ i64 ┆ str    ┆ ---      ┆   ┆ ---         ┆ i64                 ┆ ---     ┆ ---       │
# │     ┆     ┆        ┆ f64      ┆   ┆ i64         ┆                     ┆ str     ┆ i64       │
# ╞═════╪═════╪════════╪══════════╪═══╪═════════════╪═════════════════════╪═════════╪═══════════╡
# │ 1   ┆ 65  ┆ Female ┆ 6.0      ┆ … ┆ 0           ┆ 0                   ┆ Yes     ┆ 3         │
# │ 2   ┆ 69  ┆ Male   ┆ 7.0      ┆ … ┆ 0           ┆ 3                   ┆ Yes     ┆ 3         │
# │ 3   ┆ 40  ┆ Female ┆ 8.0      ┆ … ┆ 0           ┆ 0                   ┆ No      ┆ 3         │
# │ 4   ┆ 40  ┆ Female ┆ 6.0      ┆ … ┆ 50          ┆ 5                   ┆ Yes     ┆ 1         │
# ...

# %%
import requests
from bs4 import BeautifulSoup

def scrap_wiki(topic):
  url = f'https://en.wikipedia.org/wiki/{topic}'
  response = requests.get(url)

  soup = BeautifulSoup(response.text, 'html.parser')
  paragraphs = soup.find_all('p')
  for paragraph in paragraphs:
    print(paragraph.get_text())

user_input = input("Enter a topic: ")
scrap_wiki(user_input)
# Out:
# Enter a topic: football
#
#
# Football is a family of team sports that involve, to varying degrees, kicking a ball to score a goal.  Unqualified, the word football normally means the form of football that is the most popular where the word is used. Sports commonly called football include association football (known as soccer in Australia, Canada, South Africa, the United States, and sometimes in Ireland and New Zealand); Australian rules football; Gaelic football; gridiron football (specifically American football, Arena football, or Canadian football); International rules football; rugby league football; and rugby union football.[1] These various forms of football share, to varying degrees, common origins and are known as "football codes".
#
# ...

# %%
import pandas as pd
dfs = pd.read_html("https://en.wikipedia.org/wiki/Wikipedia:Popular_pages")
dfs[5]
# Out:
#     Rank                   Page  Views in millions
# 0      1           Soviet Union               63.0
# 1      2        Ottoman Empire‎               49.0
# 2      3          Roman Empire‎               43.0
# 3      4           Nazi Germany               41.0
# 4      5         British Empire               32.0
# 5      6       Byzantine Empire               28.0
# 6      7          Ancient Egypt               25.0
# 7      8          Mughal Empire               24.0
# 8      8                 Sparta               23.0
# 9     10         Russian Empire               18.0
# 10    10          German Empire               17.0
# 11    12           Qing dynasty               16.0
# 12    13  Holy Roman Empire‎[a]               15.0
# 13    13        Austria-Hungary               15.0
# 14    15            Inca Empire               13.0
# 15    15        Empire of Japan               13.0
# 16    17           Ming dynasty               11.0
# ...

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/Nameera05/Datasets/main/Sleep_Efficiency1.csv")

# %%
data
# Out:
#       ID  Age  Gender  Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0      1   65  Female             6.0              0.88                    18
# 1      2   69    Male             7.0              0.66                    19
# 2      3   40  Female             8.0              0.89                    20
# 3      4   40  Female             6.0              0.51                    23
# 4      5   57    Male             8.0              0.76                    27
# ..   ...  ...     ...             ...               ...                   ...
# 447  448   27  Female             7.5              0.91                    22
# 448  449   52    Male             6.0              0.74                    28
# 449  450   40  Female             8.5              0.55                    20
# 450  451   45    Male             7.0              0.76                    18
# 451  452   18    Male             7.5              0.63                    22
#
# ...

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=452, step=1),
#  Index(['ID', 'Age', 'Gender', 'Sleep duration', 'Sleep efficiency',
#         'REM sleep percentage', 'Deep sleep percentage',
#         'Light sleep percentage', 'Awakenings', 'Caffeine consumption',
#         'Alcohol consumption', 'Smoking status', 'Exercise frequency'],
#        dtype='object')]

# %%
data.shape
# Out:
# (452, 13)

# %%
data.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Sleep duration', 'Sleep efficiency',
#        'REM sleep percentage', 'Deep sleep percentage',
#        'Light sleep percentage', 'Awakenings', 'Caffeine consumption',
#        'Alcohol consumption', 'Smoking status', 'Exercise frequency'],
#       dtype='object')

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 5876

# %%
data.dtypes
# Out:
# ID                          int64
# Age                         int64
# Gender                     object
# Sleep duration            float64
# Sleep efficiency          float64
# REM sleep percentage        int64
# Deep sleep percentage       int64
# Light sleep percentage      int64
# Awakenings                float64
# Caffeine consumption      float64
# Alcohol consumption       float64
# Smoking status             object
# Exercise frequency        float64
# dtype: object

# %%
data.isna().sum()
# Out:
# ID                         0
# Age                        0
# Gender                     0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       14
# Smoking status             0
# Exercise frequency         6
# dtype: int64

# %%
data.isnull()
# Out:
#         ID    Age  Gender  Sleep duration  Sleep efficiency  \
# 0    False  False   False           False             False
# 1    False  False   False           False             False
# 2    False  False   False           False             False
# 3    False  False   False           False             False
# 4    False  False   False           False             False
# ..     ...    ...     ...             ...               ...
# 447  False  False   False           False             False
# 448  False  False   False           False             False
# 449  False  False   False           False             False
# 450  False  False   False           False             False
# 451  False  False   False           False             False
#
#      REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# 0                   False                  False                   False
# 1                   False                  False                   False
# ...

# %%
data.count()
# Out:
# ID                        452
# Age                       452
# Gender                    452
# Sleep duration            452
# Sleep efficiency          452
# REM sleep percentage      452
# Deep sleep percentage     452
# Light sleep percentage    452
# Awakenings                432
# Caffeine consumption      427
# Alcohol consumption       438
# Smoking status            452
# Exercise frequency        446
# dtype: int64

# %%
data.values
# Out:
# array([[1, 65, 'Female', ..., 0.0, 'Yes', 3.0],
#        [2, 69, 'Male', ..., 3.0, 'Yes', 3.0],
#        [3, 40, 'Female', ..., 0.0, 'No', 3.0],
#        ...,
#        [450, 40, 'Female', ..., 3.0, 'Yes', 0.0],
#        [451, 45, 'Male', ..., 0.0, 'No', 3.0],
#        [452, 18, 'Male', ..., 0.0, 'No', 1.0]], dtype=object)

# %%
data.head()
# Out:
#    ID  Age  Gender  Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0   1   65  Female             6.0              0.88                    18
# 1   2   69    Male             7.0              0.66                    19
# 2   3   40  Female             8.0              0.89                    20
# 3   4   40  Female             6.0              0.51                    23
# 4   5   57    Male             8.0              0.76                    27
#
#    Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                     70                      12         0.0
# 1                     28                      53         3.0
# 2                     70                      10         1.0
# 3                     25                      52         3.0
# 4                     55                      18         3.0
#
#    Caffeine consumption  Alcohol consumption Smoking status  \
# 0                   0.0                  0.0            Yes
# ...

# %%
data[data['Age']>30]
# Out:
#       ID  Age  Gender  Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0      1   65  Female             6.0              0.88                    18
# 1      2   69    Male             7.0              0.66                    19
# 2      3   40  Female             8.0              0.89                    20
# 3      4   40  Female             6.0              0.51                    23
# 4      5   57    Male             8.0              0.76                    27
# ..   ...  ...     ...             ...               ...                   ...
# 441  442   46    Male             9.0              0.60                    23
# 443  444   65  Female             7.5              0.67                    23
# 448  449   52    Male             6.0              0.74                    28
# 449  450   40  Female             8.5              0.55                    20
# 450  451   45    Male             7.0              0.76                    18
#
# ...

# %%
data['Awakenings'].mean()
data['Awakenings'].fillna(1.6412, inplace=True)

# %%
data['Caffeine consumption'].mean()
data['Caffeine consumption'].fillna(23.6533, inplace=True)

# %%
data['Alcohol consumption'].mean()
data['Alcohol consumption'].fillna(1.1735, inplace=True)

# %%
data['Exercise frequency'].mean()
data['Exercise frequency'].fillna(1.7914, inplace=True)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
data["Gender"].value_counts()
# Out:
# Gender
# Male      228
# Female    224
# Name: count, dtype: int64

# %%
data["Gender"]=le.fit_transform(data["Gender"])

# %%
data["Smoking status"] = le.fit_transform(data["Smoking status"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(9,9))
correlation= data.corr()
sns.heatmap(correlation, annot=True)
plt.show()
